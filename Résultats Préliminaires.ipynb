# %% [markdown]
# LACOUX coline <br>
# NARTZ Kévin
#
# ### Projet MADMC 2020
# # Sélection bi-objectifs avec coefficients intervalles

# %%
import matplotlib.pyplot as plt
from experiments import *
from utils import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Résultats préliminaires

# %% [markdown]
# ### Tests simples du calcul de la frontière de Pareto

# %%
vectors = generate_vectors(1000,1)

# %%
plt.scatter(vectors[:,0], vectors[:,1])
plt.title("Vecteurs tirés aléatoirement")
plt.xlabel("c1")
plt.ylabel('c2')
plt.show()

# %%
# 1er algorithme naïf
pareto, _ = naive_pareto_filter(vectors)

# %%
show_pareto_front(vectors, pareto, title="version naïve")

# %%
# 2nd algorithme naïf
pareto_fast, _ = naive_fast_pareto_filter(vectors)

# %%
show_pareto_front(vectors, pareto_fast, title="version naïve rapide")

# %%
# 3ème algorithme avec tri 
pareto_lex, _ = lexico_pareto_filter(vectors)

# %%
show_pareto_front(vectors, pareto_lex, title="version lexicographique")

# %% [markdown]
# ## Etude expérimentale de la complexité des 2 méthodes

# %% [markdown]
# ### Moyenne des temps d'exécution sur des ensembles de taille 1000 générés aléatoirement

# %% [markdown]
# #### Algorithme Naïf vs Algorithme Optimisé (moyennes sur 10 ensembles)

# %%
#times_naive, times_opti = naive_vs_sorted(naive_pareto_filter, lexico_pareto_filter, nb_iter=10)
#np.savetxt('logs/naive.csv', times_naive, delimiter=',')
#np.savetxt('logs/opti.csv', times_opti, delimiter=',')

# %%
times_naive = np.loadtxt('logs/naive.csv')
times_opti = np.loadtxt('logs/opti.csv')

# %%
x = np.arange(200, 10001, 200)
plt.figure()
plt.plot(x, times_opti,label='algorithme lexicographique')
plt.plot(x, times_naive, label="algorithme naïf")
plt.title("Temps de calcul des points Pareto non dominés")
plt.xlabel("n")
plt.ylabel('temps (s)')
plt.grid(True,which="both")
plt.legend()
plt.show()

# %%
x = np.arange(200, 10001, 200)
plt.figure()
plt.plot(x, times_opti,label='algorithme lexicographique')
plt.plot(x, times_naive, label="algorithme naïf")
plt.title("Temps de calcul des points Pareto non dominés")
plt.xlabel("n")
plt.ylabel('temps (s)')
plt.yscale('log')
plt.grid(True,which="both")
plt.legend()
plt.show()

# %% [markdown]
# #### Algorithme Naïf Rapide vs Algorithme Optimisé (moyennes sur 50 ensembles)

# %%
times_naive2, times_opti2 = naive_vs_sorted(naive_fast_pareto_filter, lexico_pareto_filter)
# Out:
# Progression: [#-------------------] 6.0%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-38566f320b02> in <module>
# ----> 1 times_naive2, times_opti2 = naive_vs_sorted(naive_fast_pareto_filter, lexico_pareto_filter)
#
# ~/Desktop/MADMC/Projet-MADMC/experiments.py in naive_vs_sorted(naive_pareto, optimized_pareto, nb_iter)
#      21         for i in range(nb_iter):
#      22             vectors = generate_vectors(n, m)
# ---> 23             pareto = naive_pareto(vectors)
#      24         time_naive = (time.time() - time_naive) / nb_iter
#      25
#
# ~/Desktop/MADMC/Projet-MADMC/utils.py in naive_fast_pareto_filter(vectors)
#      56         vector1 = vectors[i]
#      57         for vector2 in vectors:
# ---> 58             if pareto_dominate(vector2, vector1):
#      59                 mask[i] = np.full((1,d), False, dtype=bool) # point Pareto-dominé
# ...

# %%
x = np.arange(200, 10001, 200)
plt.figure()
plt.plot(x, times_opti2,label='algorithme lexicographique')
plt.plot(x, times_naive2, label="algorithme naïf rapide")
plt.title("Temps de calcul des points Pareto non dominés")
plt.xlabel("n")
plt.ylabel('temps (s)')
plt.grid(True,which="both")
plt.legend()
plt.show()

# %%
x = np.arange(200, 10001, 200)
plt.figure()
plt.plot(x, times_opti2,label='algorithme lexicographique')
plt.plot(x, times_naive2, label="algorithme naïf rapide")
plt.title("Temps de calcul des points Pareto non dominés")
plt.xlabel("n")
plt.ylabel('temps (s)')
plt.yscale('log')
plt.grid(True,which="both")
plt.legend()
plt.show()
