# %% [markdown]
# LACOUX coline <br>
# NARTZ Kévin
#
# ### Projet MADMC 2020
# # Sélection bi-objectifs avec coefficients intervalles

# %%
import matplotlib.pyplot as plt
from experiments import *
from utils import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Résultats préliminaires

# %% [markdown]
# #### Tests simples du calcul de la frontière de Pareto

# %%
vectors = generate_vectors(1000,1)

# %%
plt.scatter(vectors[:,0], vectors[:,1])
plt.title("Vecteurs tirés aléatoirement")
plt.xlabel("c1")
plt.ylabel('c2')
plt.show()

# %%
# 1er algorithme naïf
pareto = naive_pareto(vectors)

# %%
show_pareto(vectors, pareto, "version naïve")

# %%
# 2nd algorithme avec tri 
pareto_opt = optimized_pareto(vectors)

# %%
show_pareto(vectors, pareto_opt, "version optimisée")

# %% [markdown]
# ### Etude expérimentale de la complexité des 2 méthodes

# %%
naive_vs_sorted(naive_pareto, optimized_pareto)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-09e8336ba0da> in <module>
# ----> 1 naive_vs_sorted(naive_pareto, optimized_pareto)
#
# ~/Desktop/MADMC/Projet-MADMC/experiments.py in naive_vs_sorted(naive_pareto, optimized_pareto)
#      10         for i in range(50):
#      11             vectors = generate_vectors(n, m)
# ---> 12             pareto = naive_pareto(vectors)
#      13         time_naive = (time.time() - time_naive ) / 50
#      14
#
# ~/Desktop/MADMC/Projet-MADMC/utils.py in naive_pareto(vectors)
#      16                 for vector2 in vectors:
#      17                         if vector1[0] > vector2[0] and vector1[1] > vector2[1]:
# ---> 18                                 mask[i] = np.full((1,d), False, dtype=bool) # point non Pareto-optimal
#      19         pareto = vectors[mask]
#      20         return pareto.reshape((int(pareto.shape[0]/d),d))
#
# KeyboardInterrupt:
