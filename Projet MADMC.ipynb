# %% [markdown]
# LACOUX coline <br>
# NARTZ Kévin
#
# ### Projet MADMC 2020
# # Sélection bi-objectifs avec coefficients intervalles

# %%
import matplotlib.pyplot as plt
from utils import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
vectors = generate_vectors(1000,1)

# %%
plt.scatter(vectors[:,0], vectors[:,1])
plt.title("Vecteurs tirés aléatoirement")
plt.xlabel("c1")
plt.ylabel('c2')
plt.show()

# %%
print(vectors)
# Out:
# [[1.06050553 0.94393928]
#  [0.64617592 1.26144394]
#  [1.00735696 1.46011369]
#  ...
#  [0.99805013 1.1151146 ]
#  [0.78795008 0.84067023]
#  [0.90407733 1.15574826]]

# %%
pareto = naive_pareto(vectors)
print(pareto.shape)
print(pareto)
# Out:
# (7, 2)
# [[0.23613918 0.97535483]
#  [1.56149598 0.26892782]
#  [0.24677409 0.73619338]
#  [0.36733281 0.73246513]
#  [0.41781051 0.71997521]
#  [0.93252931 0.38425078]
#  [0.46899223 0.41086287]]

# %%
plt.plot()
plt.scatter(vectors[:,0], vectors[:,1])
plt.scatter(pareto[:,0], pareto[:,1])
plt.title("Front de Pareto")
plt.xlabel("c1")
plt.ylabel('c2')
plt.show()

# %%
pareto2 = optimized_pareto(vectors)
# Out:
# [[0.23613918 0.97535483]
#  [0.24677409 0.73619338]
#  [0.27431031 0.86401601]
#  ...
#  [1.65757446 1.26700049]
#  [1.69594789 1.18234099]
#  [1.69907916 0.62813599]]

# %%
plt.plot()
plt.scatter(vectors[:,0], vectors[:,1])
plt.scatter(pareto2[:,0], pareto2[:,1])
plt.title("Front de Pareto")
plt.xlabel("c1")
plt.ylabel('c2')
plt.show()
